# %%
import itertools

# %%
list(itertools.combinations([1,2,3],2))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
list(itertools.permutations([1,2,3],2))
# Out:
# [(1, 2), (1, 3), (2, 1), (2, 3), (3, 1), (3, 2)]

# %%
list(itertools.compress([1,2,3],[0,1,0]))
# Out:
# [2]
